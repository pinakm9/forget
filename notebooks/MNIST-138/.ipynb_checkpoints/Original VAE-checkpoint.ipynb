# %%
import os, sys, torch
sys.path.append(os.path.abspath('../../modules'))
sys.path.append(os.path.abspath('../../modules/mnist'))
import vae_train as vt
import vae_ortho as vo
import vae_surgery as vs
import classifier as cl
import datapipe
import utility as ut

device = ut.get_device()

# %% [markdown]
# **Train a VAE on MNIST-138**

# %%
folder = "../../data/MNIST-138/vaeu"
num_steps = 20000
batch_size = 100 
collect_interval = "epoch"
all_digits = [1, 3, 8]
log_interval = "epoch"
classifier_path = '../../data/MNIST-138/classifiers/MNISTClassifier.pth'

kl_weight = 1e0
uniformity_weight = 1e3

vt.train(None, folder, num_steps, batch_size, collect_interval=collect_interval, log_interval=log_interval, all_digits=all_digits,\
         classifier_path=classifier_path, kl_weight=kl_weight, uniformity_weight=uniformity_weight)
# Out:
# Epochs: 100%|█████████████████████████████████| 107/107 [05:10<00:00,  2.90s/it]
# Corrupt JPEG data: premature end of data segment
# Video saved at ../../data/MNIST-138/vaeu/samples/sample_evolution.mp4
# Time taken by summarize_training is 2.3592 seconds

# %% [markdown]
# **Run ou-step on vaeu**

# %%
model_path = "../../data/MNIST-138/vaeu/checkpoints/vae_epoch_107.pth"
folder = "../../data/MNIST-138/vaeu-ou"
num_steps = 1000
batch_size = 100
log_interval = 10
collect_interval = "epoch"

all_digits = [1, 3, 8]
classifier_path = '../../data/MNIST-138/classifiers/MNISTClassifier.pth'

kl_weight = 1e0
uniformity_weight = 0
orthogonality_weight = 1e5

vo.train(model_path, folder, num_steps, batch_size, collect_interval=collect_interval,\
         orthogonality_weight=orthogonality_weight, log_interval=log_interval,\
         all_digits=all_digits, classifier_path=classifier_path)
# Out:
# Epochs: 100%|███████████████████████████████████| 15/15 [01:28<00:00,  5.91s/it]
# Video saved at ../../data/MNIST-138/vaeu-ou/samples/sample_evolution.mp4
# Time taken by summarize_training is 0.6247 seconds

# %% [markdown]
# **Run su-step on vaeu-ou**

# %%
model_path = "../../data/MNIST-138/vaeu-ou/checkpoints/vae_epoch_1.pth"
folder = "../../data/MNIST-138/vaeu-ou-su"
num_steps = 1000
batch_size = 100
log_interval = 10
collect_interval = "epoch"

all_digits = [1, 3, 8]
forget_digit = 1
classifier_path = '../../data/MNIST-138/classifiers/MNISTClassifier.pth'

kl_weight = 1e0
uniformity_weight = 1e3

vs.train(model_path, folder, num_steps, batch_size, collect_interval=collect_interval, log_interval=log_interval,\
         all_digits=all_digits, forget_digit=forget_digit, classifier_path=classifier_path)
# Out:
# Epochs: 100%|███████████████████████████████████| 15/15 [01:25<00:00,  5.68s/it]
# Video saved at ../../data/MNIST-138/vaeu-ou-su/samples/sample_evolution.mp4
# Time taken by summarize_training is 0.7155 seconds

# %%
cl.train("../../data/MNIST/classifiers", cl.MNISTClassifier, 100, 1000, all_digits=list(range(10)))
# Out:
# Epochs: 100%|█| 100/100 [02:21<00:00,  1.41s/epoch, loss=0.0000, test_acc=98.21%

# %%
set(range(10)) == set(range(19))
# Out:
# False

# %%
dl = datapipe.MNIST().get_dataloader(100)
img, _ = next(iter(dl))
img = img.to(device)
identifier = cl.get_classifier('../../data/MNIST-138/classifiers/MNISTClassifier.pth', 'mps')

# %%
cl.frechet_inception_distance(img, img, identifier)
# Out:
# -4.449436029188569e-06

# %%
c = ut.get_config(folder)

# %%
torch.linalg.eigh(img,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 torch.linalg.eigh(img, PYTORCH_ENABLE_MPS_FALLBACK=1)
#
# TypeError: linalg_eigh() got an unexpected keyword argument 'PYTORCH_ENABLE_MPS_FALLBACK'

# %%
logits = identifier(img)
torch.bincount(torch.argmax(logits, dim=1), minlength=10)
# Out:
# tensor([ 0, 20,  0, 31,  0,  0,  0,  0, 49,  0], device='mps:0')

# %%
help(torch.bincount)
# Out:
# Help on built-in function bincount in module torch:
#
# bincount(...)
#     bincount(input, weights=None, minlength=0) -> Tensor
#
#     Count the frequency of each value in an array of non-negative ints.
#
#     The number of bins (size 1) is one larger than the largest value in
#     :attr:`input` unless :attr:`input` is empty, in which case the result is a
#     tensor of size 0. If :attr:`minlength` is specified, the number of bins is at least
#     :attr:`minlength` and if :attr:`input` is empty, then the result is tensor of size
#     :attr:`minlength` filled with zeros. If ``n`` is the value at position ``i``,
#     ``out[n] += weights[i]`` if :attr:`weights` is specified else
#     ``out[n] += 1``.
#
#     Note:
#         This operation may produce nondeterministic gradients when given tensors on a CUDA device. See :doc:`/notes/randomness` for more information.
#
#     Arguments:
#         input (Tensor): 1-d int tensor
#         weights (Tensor): optional, weight for each value in the input tensor.
#             Should be of same size as input tensor.
#         minlength (int): optional, minimum number of bins. Should be non-negative.
#
#     Returns:
#         output (Tensor): a tensor of shape ``Size([max(input) + 1])`` if
#         :attr:`input` is non-empty, else ``Size(0)``
#
#     Example::
#
#         >>> input = torch.randint(0, 8, (5,), dtype=torch.int64)
#         >>> weights = torch.linspace(0, 1, steps=5)
#         >>> input, weights
#         (tensor([4, 3, 6, 3, 4]),
#          tensor([ 0.0000,  0.2500,  0.5000,  0.7500,  1.0000])
#
#         >>> torch.bincount(input)
#         tensor([0, 0, 0, 2, 2, 0, 1])
#
#         >>> input.bincount(weights)
#         tensor([0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.5000])
